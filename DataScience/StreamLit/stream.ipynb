# %%
import yfinance as yf

# %%
data = yf.download(tickers="AMZN", start= "2020-01-01" , end="2022-02-01" , interval = '1d')

# %%
data

# %%
type(data)

# %%
import requests

from bs4 import BeautifulSoup

res = requests.get("https://google.com/search?q=btc+on+yahoo+finance")

# %%
soup = BeautifulSoup(res.content, 'html.parser')

# %%
BeautifulSoup(requests.get("https://google.com/search?q=btc+on+yahoo+finance").content, 'html.parser').find_all('a')

# %%
BeautifulSoup(requests.get("https://google.com/search?q=amaazon+on+yahoo+finance").content, 'html.parser').find_all('a')

# %%
import re

# %%
pattern = r'''<a href="/url\?q=https://finance.yahoo.com/quote/([A-Z|\-]+)'''  

x = re.findall(pattern, str(BeautifulSoup(requests.get("https://google.com/search?q=wioproo+on+yahoo+finance").content, 'html.parser').find_all('a')))

asset_name = str(BeautifulSoup(requests.get(f"https://finance.yahoo.com/quote/{x[0]}").content, 'html.parser').find_all('h1'))

# %%
asset_name

# %%
asset_name

# %%
pattern = r"<h1 class=\"D(.*?)\">(.*?)<\/h1>"

x = re.findall(pattern, asset_name)[0][1]
print(x)

pattern = r"\("

x = re.split("\(", x)

x

# %%
import streamlit as st
import pandas as pd
import base64
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
url = "https://www.basketball-reference.com/leagues/NBA_" + "2011" + "_per_game.html"

html = pd.read_html(url, header = 0)

html[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1     Jeff Adrien  PF  24  GSW  23   0   8.5  1.0   2.3  ...  .579
# 1      2   Arron Afflalo  SG  25  DEN  69  69  33.7  4.5   9.1  ...  .847
# 2      3    Maurice Ager  SG  26  MIN   4   0   7.3  1.5   2.8  ...   NaN
# 3      4   Alexis Ajinça   C  22  TOT  34   2  10.0  1.7   3.9  ...  .722
# 4      4   Alexis Ajinça   C  22  DAL  10   2   7.5  1.2   3.2  ...  .667
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 642  448   Dorell Wright  SF  25  GSW  82  82  38.4  5.9  14.0  ...  .789
# 643  449   Julian Wright  SF  23  TOR  52   6  14.7  1.6   3.1  ...  .512
# 644  450      Nick Young  SG  25  WAS  64  40  31.8  6.4  14.6  ...  .816
# 645  451       Sam Young  SF  25  MEM  78  46  20.2  3.0   6.3  ...  .767
# 646  452  Thaddeus Young  PF  22  PHI  82   1  26.0  5.6  10.3  ...  .707
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0    1.0  1.5  2.5  0.4  0.2  0.2  0.4  1.2   2.5
# 1    0.7  3.0  3.6  2.4  0.5  0.4  1.0  2.2  12.6
# 2    0.0  0.5  0.5  0.3  0.3  0.0  1.0  1.0   3.8
# 3    0.5  1.8  2.3  0.3  0.3  0.6  0.5  2.1   4.2
# 4    0.5  1.2  1.7  0.2  0.3  0.5  0.1  1.3   2.9
# ..   ...  ...  ...  ...  ...  ...  ...  ...   ...
# 642  1.1  4.2  5.3  3.0  1.5  0.8  1.6  2.1  16.4
# 643  0.9  1.4  2.3  1.1  0.8  0.4  0.8  0.9   3.6
# 644  0.4  2.3  2.7  1.2  0.7  0.3  1.4  2.3  17.4
# 645  0.5  1.9  2.4  0.9  0.9  0.3  0.8  1.5   7.3
# 646  1.9  3.4  5.3  1.0  1.1  0.3  1.2  2.1  12.7
#
# [647 rows x 30 columns]

# %%
df = html[0]
raw = df.drop(df[df.Age == 'Age'].index) # Deletes repeating headers in content
raw = raw.fillna(0)
playerstats = raw.drop(['Rk'], axis=1)
playerstats
# Out:
#              Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...   FT%  \
# 0       Jeff Adrien  PF  24  GSW  23   0   8.5  1.0   2.3  .426  ...  .579
# 1     Arron Afflalo  SG  25  DEN  69  69  33.7  4.5   9.1  .498  ...  .847
# 2      Maurice Ager  SG  26  MIN   4   0   7.3  1.5   2.8  .545  ...     0
# 3     Alexis Ajinça   C  22  TOT  34   2  10.0  1.7   3.9  .444  ...  .722
# 4     Alexis Ajinça   C  22  DAL  10   2   7.5  1.2   3.2  .375  ...  .667
# ..              ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...   ...
# 642   Dorell Wright  SF  25  GSW  82  82  38.4  5.9  14.0  .423  ...  .789
# 643   Julian Wright  SF  23  TOR  52   6  14.7  1.6   3.1  .513  ...  .512
# 644      Nick Young  SG  25  WAS  64  40  31.8  6.4  14.6  .441  ...  .816
# 645       Sam Young  SF  25  MEM  78  46  20.2  3.0   6.3  .472  ...  .767
# 646  Thaddeus Young  PF  22  PHI  82   1  26.0  5.6  10.3  .541  ...  .707
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0    1.0  1.5  2.5  0.4  0.2  0.2  0.4  1.2   2.5
# 1    0.7  3.0  3.6  2.4  0.5  0.4  1.0  2.2  12.6
# 2    0.0  0.5  0.5  0.3  0.3  0.0  1.0  1.0   3.8
# 3    0.5  1.8  2.3  0.3  0.3  0.6  0.5  2.1   4.2
# 4    0.5  1.2  1.7  0.2  0.3  0.5  0.1  1.3   2.9
# ..   ...  ...  ...  ...  ...  ...  ...  ...   ...
# 642  1.1  4.2  5.3  3.0  1.5  0.8  1.6  2.1  16.4
# 643  0.9  1.4  2.3  1.1  0.8  0.4  0.8  0.9   3.6
# 644  0.4  2.3  2.7  1.2  0.7  0.3  1.4  2.3  17.4
# 645  0.5  1.9  2.4  0.9  0.9  0.3  0.8  1.5   7.3
# 646  1.9  3.4  5.3  1.0  1.1  0.3  1.2  2.1  12.7
#
# [625 rows x 29 columns]

# %%
playerstats.apply(lambda x: x for x in playerstats["Tim"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tim'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-667b28d78194> in <module>
# ----> 1 playerstats.apply(lambda x: x for x in playerstats["Tim"])
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Tim'
